# %% [markdown]
# # L1: Overview of Multimodality
#
#
# This project demonstrates the use of a neural network to generate embeddings for the MNIST dataset, visualize them in low-dimensional space, and analyze feature clustering. It combines neural network training, contrastive loss, and dimensionality reduction techniques like PCA and UMAP.
#
# ---
#
# ## **Key Steps**
#
# ### 1. **Data Preprocessing**
# - MNIST dataset is split into training and validation sets.
# - Image transformations include:
#   - Conversion to PIL format.
#   - Normalization to scale pixel values between `[-1, 1]`.
#
# ### 2. **Neural Network**
# - A CNN with two convolutional layers and one fully connected layer outputs 64-dimensional embeddings.
# - **Dropout** and **Batch Normalization** are applied for regularization.
#
# ### 3. **Contrastive Loss**
# - Minimizes the distance between embeddings of similar samples (positive pairs).
# - Maximizes the distance between embeddings of dissimilar samples (negative pairs).
# - Uses **cosine similarity** for embedding comparison.
#
# ### 4. **Visualization**
# - **PCA** reduces embeddings from 64D to 3D for interactive plots.
# - **UMAP** reduces embeddings to 2D:
#   - **Cosine Similarity** for directional relationships.
#   - **Euclidean Distance** for geometric clustering.

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# * In this classroom, the libraries have been already installed for you.
# * If you would like to run this code on your own machine, you need to install the following:
# ```
#     !pip install -q accelerate torch
#     !pip install -U scikit-learn
#     !pip install umap-learn
#     !pip install tqdm
# ```

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import libraries
# - `import torch`:PyTorch is a popular deep learning framework used to create and train neural networks.
# - `from torch import nn, optim`:
#     - nn: Contains modules for building neural networks (e.g., layers, activation functions, loss functions).
#     - optim: Includes optimization algorithms like SGD, Adam, etc., used for training models.
# - `from torch.utils.data import DataLoader`: A utility for loading and batching datasets efficiently, crucial for training models on large datasets.
# - `from torchvision import transforms`: Provides common data transformation utilities (e.g., resizing, normalization) for image data, particularly for datasets like MNIST.
# - `from sklearn.decomposition import PCA`: PCA (Principal Component Analysis) is a technique for reducing the dimensionality of data, often used for visualization or preprocessing.
# - `import umap`: UMAP (Uniform Manifold Approximation and Projection) is a non-linear dimensionality reduction technique, often used to visualize high-dimensional data in 2D or 3D.

# %%
# Import neural network training libraries
import torch
from torch import nn, optim
from torch.utils.data import DataLoader
from torchvision import transforms

# Import basic computation libraries along with data visualization and plotting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
# Dimensionality Reduction and Visualization
from sklearn.decomposition import PCA
import umap
import umap.plot
import plotly.graph_objs as go
import plotly.io as pio
pio.renderers.default = 'iframe'

# Import our data class which will organize MNIST and provide anchor, positive and negative samples.
from mnist_dataset import MNISTDataset

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access Utils File and Helper Functions:</b> To access the <code>mnist_dataset.py</code> and other files for this notebook, 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Load MNIST Dataset
# - `transforms.ToPILImage()`: Converts the input (usually a NumPy array or a PyTorch Tensor) into a PIL (Python Imaging Library) image for further processing.
# - `transforms.ToTensor()`:
#     - Converts the PIL image or NumPy array into a PyTorch Tensor.
#     - Pixel values are scaled from [0, 255] (integer) to [0, 1] (float).
# - `transforms.Normalize(0.5, 0.5)`: Each pixel value is adjusted using the formula: x' = (x-0.5)/0.5, This rescales pixel values from [0, 1] to [-1, 1].

# %%
# Load data from csv
data = pd.read_csv('digit-recognizer/train.csv')
val_count = 1000
# common transformation for both val and train
default_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
    transforms.Normalize(0.5, 0.5)
])

# Split data into val and train
dataset = MNISTDataset(data.iloc[:-val_count], default_transform)
val_dataset = MNISTDataset(data.iloc[-val_count:], default_transform)
# Out:
# 100%|██████████| 41000/41000 [00:07<00:00, 5477.70it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 5627.65it/s]

# %% [markdown]
# ## Setup our DataLoaders

# %%
# Create torch dataloaders
trainLoader = DataLoader(
    dataset,
    batch_size=16, # feel free to modify this value
    shuffle=True,
    pin_memory=True,
    num_workers=2,
    # Specifies the number of batches to prefetch for each worker.
    prefetch_factor=100
)

valLoader = DataLoader(
    val_dataset,
    batch_size=64,
    shuffle=True,
    pin_memory=True,
    num_workers=2,
    prefetch_factor=100
)

# %% [markdown]
# ### Visualize datapoints

# %%
# Function to display images with labels
def show_images(images, title=''):
    num_images = len(images)
    # Creates a grid of subplots with 1 row and num_images columns.
    fig, axes = plt.subplots(1, num_images, figsize=(9, 3))
    for i in range(num_images):
        # if an image has a shape like (1, 28, 28), it becomes (28, 28).
        img = np.squeeze(images[i])
        axes[i].imshow(img, cmap='gray')
        axes[i].axis('off')
    fig.suptitle(title)
    plt.show()

# Visualize some examples
for batch_idx, (anchor_images, contrastive_images, distances, labels) in enumerate(trainLoader):
    # Convert tensors to numpy arrays, because the visualization library (Matplotlib) works with NumPy arrays.
    anchor_images = anchor_images.numpy()
    contrastive_images = contrastive_images.numpy()
    labels = labels.numpy()

    # Display some samples from the batch
    show_images(anchor_images[:4], title='Anchor Image')
    show_images(contrastive_images[:4], title='Contrastive Example')

    # Break after displaying one batch for demonstration
    break

# %% [markdown]
# > Note: Please be aware that the output from the previous cell may differ from what is shown in the video. This variation is normal and should not cause concern.

# %% [markdown]
# ## Build Neural Network Architecture

# %%
# Define a neural network architecture with two convolution layers and two fully connected layers
# Input to the network is an MNIST image and Output is a 64 dimensional representation. 
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 32, 5),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d((2, 2), stride=2),
            nn.Dropout(0.3)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, 5),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d((2, 2), stride=2),
            nn.Dropout(0.3)
        )
        self.linear1 = nn.Sequential(
            nn.Linear(64 * 4 * 4, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(512, 64),
        )

    def forward(self, x):
        x = self.conv1(x) # x: d * 32 * 12 * 12
        x = self.conv2(x) # x: d * 64 * 4  * 4 
        x = x.view(x.size(0), -1) # x: d * (64*4*4)
        x = self.linear1(x) # x: d * 64
        return x

# %% [markdown]
# ## Contrastive Loss Function

# %%
# The ideal distance metric for a positive sample is set to 1, for a negative sample it is set to 0      
class ContrastiveLoss(nn.Module):
    def __init__(self):
        super(ContrastiveLoss, self).__init__()
        self.similarity = nn.CosineSimilarity(dim=-1, eps=1e-7)

    def forward(self, anchor, contrastive, distance):
        # use cosine similarity from torch to get score
        score = self.similarity(anchor, contrastive)
        # after cosine apply MSE between distance and score
        return nn.MSELoss()(score, distance) #Ensures that the calculated score is close to the ideal distance (1 or 0)

# %% [markdown]
# #### Define the Training Configuration

# %%
net = Network()

device = 'cpu'
if torch.cuda.is_available():
    device = torch.device('cuda:0')
    
net = net.to(device)
device
# Out:
# 'cpu'

# %%
# Define the training configuration
optimizer = optim.Adam(net.parameters(), lr=0.005)
loss_function = ContrastiveLoss()
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.3)

# %% [markdown]
# ## Training Loop

# %%
import os

# Define a directory to save the checkpoints
checkpoint_dir = 'checkpoints/'

# Ensure the directory exists
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

# %% [markdown]
# ### Model Training

# %%
def train_model(epoch_count=10):#
    net = Network()
    lrs = []
    losses = []

    for epoch in range(epoch_count):
        epoch_loss = 0
        batches=0
        print('epoch -', epoch)
        lrs.append(optimizer.param_groups[0]['lr'])
        print('learning rate', lrs[-1])
    
        for anchor, contrastive, distance, label in tqdm(trainLoader):
            batches += 1
            # Clears gradients from the previous batch using optimizer.zero_grad() to prevent accumulation.
            optimizer.zero_grad()
            # Pass Inputs Through the Network
            anchor_out = net(anchor.to(device))
            contrastive_out = net(contrastive.to(device))
            distance = distance.to(torch.float32).to(device)
            loss = loss_function(anchor_out, contrastive_out, distance)
            epoch_loss += loss
            # Computes gradients via backpropagation
            loss.backward()
            # Updates the model's weights based on the computed gradients.
            optimizer.step()

        losses.append(epoch_loss.cpu().detach().numpy() / batches)
        # Updates the learning rate using the learning rate scheduler.
        scheduler.step()
        print('epoch_loss', losses[-1])
    
        # Save a checkpoint of the model
        checkpoint_path = os.path.join(checkpoint_dir, f'model_epoch_{epoch}.pt')
        torch.save(net.state_dict(), checkpoint_path)

    return {
        "net": net,
        "losses": losses
    }

# %% [markdown]
# >Note: The model presented above is ready for training; however, please be aware that it may take several minutes to train. As a backup plan, we provide the option to load a pre-trained model.

# %% [markdown]
# ### Load from Backup

# %%
def load_model_from_checkpoint():
    checkpoint = torch.load('checkpoints/model_epoch_99.pt')
    
    net = Network()
    net.load_state_dict(checkpoint)
    net.eval()

    return net

# %% [markdown]
# Set the `train` variable to `TRUE` if you'd like to train the model, otherwise you will load a trained checkpoint of the model.

# %% [markdown]
# ### Get the Model

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> <b>(Note: <code>train = False</code>):</b> We've saved the trained model and are loading it here for speedier results, allowing you to observe the outcomes faster. Once you've done an initial run, you may set <code>train</code> to <code>True</code> to train the model yourself. This can take some time to finsih, depending the value you set for the <code>epoch_count</code>.</p>

# %%
train = False # set to True to run train the model

if train:
    training_result = train_model()
    model = training_result["net"]
else:
    model = load_model_from_checkpoint()

# %% [markdown]
# ### Visualize the loss curve for your trained model

# %%
from IPython.display import Image

if train:
    # show loss curve from your training.
    plt.plot(training_result["losses"])
    plt.show()
else:
    # If you are loading a checkpoint instead of training the model (train = False),
    # the following line will show a pre-saved loss curve from the checkpoint data.
    display(Image(filename="images/loss-curve.png", height=600, width=600))

# %% [markdown]
# ## Visualize the Vector Space!

# %% [markdown]
# ### Generate 64d Representations of the Training Set

# %%
encoded_data = []
labels = []
# Reduces memory usage and speeds up processing since gradients are not needed for generating embeddings.
with torch.no_grad():
    for anchor, _, _, label in tqdm(trainLoader):
        output = model(anchor.to(device))
        encoded_data.extend(output.cpu().numpy())
        labels.extend(label.cpu().numpy())

encoded_data = np.array(encoded_data)
labels = np.array(labels)
# Out:
#   0%|          | 0/2563 [00:00<?, ?it/s]

# %% [markdown]
# ### Reduce Dimensionality of Data: 64d -> 3d

# %%
# Apply PCA to reduce dimensionality of data from 64d -> 3d to make it easier to visualize!
pca = PCA(n_components=3)
encoded_data_3d = pca.fit_transform(encoded_data)

# %% [markdown]
# ### Interactive Scatter Plot in 3d – with PCA

# %%
scatter = go.Scatter3d(
    x=encoded_data_3d[:, 0],
    y=encoded_data_3d[:, 1],
    z=encoded_data_3d[:, 2],
    mode='markers',
    marker=dict(size=4, color=labels, colorscale='Viridis', opacity=0.8),
    text=labels, 
    hoverinfo='text',
)

# Create layout
layout = go.Layout(
    title="MNIST Dataset - Encoded and PCA Reduced 3D Scatter Plot",
    scene=dict(
        xaxis=dict(title="PC1"),
        yaxis=dict(title="PC2"),
        zaxis=dict(title="PC3"),
    ),
    width=1000, 
    height=750,
)

# Create figure and add scatter plot
fig = go.Figure(data=[scatter], layout=layout)

# Show the plot
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="1020px"
#     height="770"
#     src="iframe_figures/figure_17.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Scatterplot in 2d - with UMAP
# - Use `Cosine Similarity` if:
#     Your data is **normalized or represents directional relationships** (e.g., embeddings for text, images, or documents).
#
#     You are working with **semantic similarity or vector embeddings**.

# %%
mapper = umap.UMAP(random_state=42, metric='cosine').fit(encoded_data)
umap.plot.points(mapper, labels=labels);

# %% [markdown]
# > Note: Please be aware that the output from the previous cell may differ from what is shown in the video. This variation is normal and should not cause concern. Also the previous cell might take some minutes to run.

# %% [markdown]
# ### UMAP with Euclidian Metric
# - Use `Euclidean Distance` if:
#
#     Your data has meaningful **magnitude differences**, such as physical distances, raw pixel values, or unnormalized data.
#
#     You are working with **raw numerical data or geometric relationships**.

# %%
mapper = umap.UMAP(random_state=42).fit(encoded_data) 
umap.plot.points(mapper, labels=labels);

# %% [markdown]
# > Note: Please be aware that the output from the previous cell may differ from what is shown in the video. This variation is normal and should not cause concern.

# %% [markdown]
# ## Contrastive Training over 100 Epochs!

# %%
# Run it to see the training!
from IPython.display import Video
Video("contrastive_Training_100.mp4", height=500)
# Out:
# <video src="contrastive_Training_100.mp4" controls   height="500">
#       Your browser does not support the <code>video</code> element.
#     </video>
